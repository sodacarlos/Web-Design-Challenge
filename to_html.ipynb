# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
cities = "Resources/cities.csv"

df = pd.read_csv(cities)

# %%
df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          0          kapaa  22.0752 -159.3190     26.99        77
# 1          1         barrow  71.2906 -156.7887     -5.99        86
# 2          2      busselton -33.6500  115.3333     13.33        68
# 3          3  mar del plata -38.0023  -57.5575     16.08        59
# 4          4          vaini -21.2000 -175.2000     23.09        88
# ..       ...            ...      ...       ...       ...       ...
# 546      546    poshekhonye  58.4993   39.1353      2.33        90
# 547      547  santa rosalia  27.3167 -112.2833     26.61        33
# 548      548      boqueirao  -7.5000  -36.1333     26.75        73
# 549      549      panyutyne  48.9333   36.2833     10.82        56
# 550      550         quibor   9.9287  -69.6201     30.84        39
#
#      Cloudiness  Wind Speed Country        Date
# 0            40        6.17      US  1651608887
# 1           100        5.14      US  1651608707
# ...

# %%
df.set_index(df["City_ID"], inplace=True)
df
# Out:
#          City_ID           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0              0          kapaa  22.0752 -159.3190     26.99        77
# 1              1         barrow  71.2906 -156.7887     -5.99        86
# 2              2      busselton -33.6500  115.3333     13.33        68
# 3              3  mar del plata -38.0023  -57.5575     16.08        59
# 4              4          vaini -21.2000 -175.2000     23.09        88
# ...          ...            ...      ...       ...       ...       ...
# 546          546    poshekhonye  58.4993   39.1353      2.33        90
# 547          547  santa rosalia  27.3167 -112.2833     26.61        33
# 548          548      boqueirao  -7.5000  -36.1333     26.75        73
# 549          549      panyutyne  48.9333   36.2833     10.82        56
# 550          550         quibor   9.9287  -69.6201     30.84        39
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# ...

# %%
df.drop(columns=["City_ID"], inplace=True)
df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kapaa  22.0752 -159.3190     26.99        77          40
# 1               barrow  71.2906 -156.7887     -5.99        86         100
# 2            busselton -33.6500  115.3333     13.33        68          84
# 3        mar del plata -38.0023  -57.5575     16.08        59           0
# 4                vaini -21.2000 -175.2000     23.09        88          20
# ...                ...      ...       ...       ...       ...         ...
# 546        poshekhonye  58.4993   39.1353      2.33        90         100
# 547      santa rosalia  27.3167 -112.2833     26.61        33          98
# 548          boqueirao  -7.5000  -36.1333     26.75        73          25
# 549          panyutyne  48.9333   36.2833     10.82        56          29
# 550             quibor   9.9287  -69.6201     30.84        39          17
#
#          Wind Speed Country        Date
# City_ID
# ...

# %%
df.to_html("cities.html")
